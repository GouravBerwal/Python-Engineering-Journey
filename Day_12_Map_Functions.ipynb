# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟏 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙙𝙤𝙪𝙗𝙡𝙚 𝙚𝙫𝙚𝙧𝙮 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙣 𝙖 𝙜𝙞𝙫𝙚𝙣 𝙡𝙞𝙨𝙩.

# %%
numbers = [1, 2, 3, 4, 5]
double = lambda x: x * 2
result = map(double,numbers)
print(list(result))
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟐 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙨𝙦𝙪𝙖𝙧𝙚 𝙚𝙫𝙚𝙧𝙮 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙣 𝙖 𝙜𝙞𝙫𝙚𝙣 𝙡𝙞𝙨𝙩.

# %%
numbers = [2, 4, 6, 8]
square = lambda x: x ** 2
result = map(square,numbers)
print(list(result))
# Out:
# [4, 16, 36, 64]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟑 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙖𝙙𝙙 𝟏𝟎 𝙩𝙤 𝙚𝙫𝙚𝙧𝙮 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙣 𝙖 𝙜𝙞𝙫𝙚𝙣 𝙡𝙞𝙨𝙩.

# %%
numbers = [5, 10, 15, 20]
add = map(lambda x: x + 10, numbers)
print(list(add))
# Out:
# [15, 20, 25, 30]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟒 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙤𝙣𝙫𝙚𝙧𝙩 𝙚𝙫𝙚𝙧𝙮 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙣 𝙖 𝙡𝙞𝙨𝙩 𝙞𝙣𝙩𝙤 𝙞𝙩𝙨 𝙨𝙦𝙪𝙖𝙧𝙚.

# %%
numbers = [3, 5, 7, 9]
square = map(lambda x : x ** 2, numbers)
print(list(square))
# Out:
# [9, 25, 49, 81]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟓 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙤𝙣𝙫𝙚𝙧𝙩 𝙚𝙫𝙚𝙧𝙮 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙣𝙩𝙤 𝙞𝙩𝙨 𝙙𝙤𝙪𝙗𝙡𝙚 𝙞𝙛 𝙞𝙩 𝙞𝙨 𝙚𝙫𝙚𝙣, 𝙤𝙩𝙝𝙚𝙧𝙬𝙞𝙨𝙚 𝙩𝙧𝙞𝙥𝙡𝙚 𝙞𝙩.

# %%
numbers = [2, 3, 4, 5, 6]
convert = map(lambda x: x * 2 if x % 2 == 0 else x * 3, numbers)
print(list(convert))
# Out:
# [4, 9, 8, 15, 12]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟔 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙖𝙙𝙙 𝟓% 𝙩𝙤 𝙚𝙫𝙚𝙧𝙮 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙣 𝙖 𝙡𝙞𝙨𝙩.

# %%
numbers = [100, 200, 300, 400]
percent = map(lambda x: x + x * 0.05, numbers)
print(list(percent))
# Out:
# [105.0, 210.0, 315.0, 420.0]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟕 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙤𝙣𝙫𝙚𝙧𝙩 𝙚𝙫𝙚𝙧𝙮 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙣 𝙖 𝙡𝙞𝙨𝙩 𝙞𝙣𝙩𝙤 𝙞𝙩𝙨 𝙖𝙗𝙨𝙤𝙡𝙪𝙩𝙚 𝙫𝙖𝙡𝙪𝙚.

# %%
numbers = [-10, 20, -30, 40, -50]
absolute = map(lambda x: -x if x < 0 else x, numbers)
print(list(absolute))
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟖 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙤𝙣𝙫𝙚𝙧𝙩 𝙚𝙫𝙚𝙧𝙮 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙣𝙩𝙤 "𝙀𝙫𝙚𝙣" 𝙤𝙧 "𝙊𝙙𝙙".

# %%
numbers = [10, 15, 22, 31, 40]
convert = map(lambda x: "Even" if x % 2 == 0 else "Odd", numbers)
print(list(convert))
# Out:
# ['Even', 'Odd', 'Even', 'Odd', 'Even']

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟎𝟗 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙖𝙥𝙞𝙩𝙖𝙡𝙞𝙯𝙚 𝙩𝙝𝙚 𝙛𝙞𝙧𝙨𝙩 𝙡𝙚𝙩𝙩𝙚𝙧 𝙤𝙛 𝙚𝙫𝙚𝙧𝙮 𝙣𝙖𝙢𝙚 𝙞𝙣 𝙖 𝙡𝙞𝙨𝙩.

# %%
letters = ["gourav", "rahul", "aman", "rohit"]
capital = map(lambda x: x[0].upper() + x[1:].lower(), letters)
print(list(capital))
# Out:
# ['Gourav', 'Rahul', 'Aman', 'Rohit']

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟎 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙖𝙡𝙘𝙪𝙡𝙖𝙩𝙚 𝙩𝙝𝙚 𝙛𝙞𝙣𝙖𝙡 𝙥𝙧𝙞𝙘𝙚 𝙖𝙛𝙩𝙚𝙧 𝙖 𝟏𝟎% 𝙙𝙞𝙨𝙘𝙤𝙪𝙣𝙩 𝙛𝙤𝙧 𝙚𝙫𝙚𝙧𝙮 𝙞𝙩𝙚𝙢 𝙥𝙧𝙞𝙘𝙚 𝙞𝙣 𝙖 𝙡𝙞𝙨𝙩.

# %%
numbers = [500, 1000, 1500, 2000]
discount = map(lambda x: x - x * 0.10, numbers)
print(list(discount))
# Out:
# [450.0, 900.0, 1350.0, 1800.0]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟏 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙤𝙣𝙫𝙚𝙧𝙩 𝙩𝙚𝙢𝙥𝙚𝙧𝙖𝙩𝙪𝙧𝙚𝙨 𝙛𝙧𝙤𝙢 𝘾𝙚𝙡𝙨𝙞𝙪𝙨 𝙩𝙤 𝙁𝙖𝙝𝙧𝙚𝙣𝙝𝙚𝙞𝙩.

# %%
temperature = [0, 10, 20, 30, 40]
celcius = map(lambda x: (x * 9/5) + 32, temperature)
print(list(celcius))
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟐 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙤𝙪𝙣𝙩 𝙩𝙝𝙚 𝙣𝙪𝙢𝙗𝙚𝙧 𝙤𝙛 𝙘𝙝𝙖𝙧𝙖𝙘𝙩𝙚𝙧𝙨 𝙞𝙣 𝙚𝙫𝙚𝙧𝙮 𝙬𝙤𝙧𝙙 𝙞𝙣 𝙖 𝙡𝙞𝙨𝙩.

# %%
character = ["Python", "SQL", "Excel", "Data"]
count = map(lambda x: len(x), character)
print(list(count))
# Out:
# [6, 3, 5, 4]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟑 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙖𝙙𝙙 𝙩𝙝𝙚 𝙛𝙞𝙧𝙨𝙩 𝙖𝙣𝙙 𝙡𝙖𝙨𝙩 𝙙𝙞𝙜𝙞𝙩 𝙤𝙛 𝙚𝙫𝙚𝙧𝙮 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙣 𝙖 𝙡𝙞𝙨𝙩.

# %%
numbers = [123, 456, 789, 102]
add = map(lambda x: int(str(x)[0]) + int(str(x)[-1]), numbers)
print(list(add))
# Out:
# [4, 10, 16, 3]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟒 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙧𝙚𝙥𝙡𝙖𝙘𝙚 𝙚𝙫𝙚𝙧𝙮 𝙣𝙚𝙜𝙖𝙩𝙞𝙫𝙚 𝙣𝙪𝙢𝙗𝙚𝙧 𝙬𝙞𝙩𝙝 𝟎, 𝙬𝙝𝙞𝙡𝙚 𝙠𝙚𝙚𝙥𝙞𝙣𝙜 𝙥𝙤𝙨𝙞𝙩𝙞𝙫𝙚 𝙣𝙪𝙢𝙗𝙚𝙧𝙨 𝙪𝙣𝙘𝙝𝙖𝙣𝙜𝙚𝙙.

# %%
numbers = [-5, 10, -2, 0, 8, -7]
replace = map(lambda x: 0 if x < 0 else x, numbers)
print(list(replace))
# Out:
# [0, 10, 0, 0, 8, 0]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟓 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙢𝙪𝙡𝙩𝙞𝙥𝙡𝙮 𝙚𝙖𝙘𝙝 𝙣𝙪𝙢𝙗𝙚𝙧 𝙗𝙮 𝟐 𝙞𝙛 𝙞𝙩 𝙞𝙨 𝙥𝙤𝙨𝙞𝙩𝙞𝙫𝙚, 𝙖𝙣𝙙 𝙗𝙮 𝟑 𝙞𝙛 𝙞𝙩 𝙞𝙨 𝙣𝙚𝙜𝙖𝙩𝙞𝙫𝙚.

# %%
numbers = [-5, 10, -2, 4, 0]
multiply = map(lambda x: x * 2 if x > 0 else x * 3, numbers)
print(list(multiply))
# Out:
# [-15, 20, -6, 8, 0]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟔 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙤𝙣𝙫𝙚𝙧𝙩 𝙚𝙫𝙚𝙧𝙮 𝙣𝙪𝙢𝙗𝙚𝙧 𝙞𝙣𝙩𝙤: "𝙋𝙤𝙨𝙞𝙩𝙞𝙫𝙚" 𝙞𝙛 𝙣𝙪𝙢𝙗𝙚𝙧 > 𝟎 "𝙉𝙚𝙜𝙖𝙩𝙞𝙫𝙚" 𝙞𝙛 𝙣𝙪𝙢𝙗𝙚𝙧 < 𝟎 "𝙕𝙚𝙧𝙤" 𝙞𝙛 𝙣𝙪𝙢𝙗𝙚𝙧 == 𝟎.

# %%
numbers = [-10, 20, 0, -5, 8]
convert = map(lambda x: "Positive" if x > 0 else "Negative" if x < 0 else "Zero", numbers)
print(list(convert))
# Out:
# ['Negative', 'Positive', 'Zero', 'Negative', 'Positive']

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟕 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙧𝙚𝙢𝙤𝙫𝙚 𝙚𝙭𝙩𝙧𝙖 𝙨𝙥𝙖𝙘𝙚𝙨 𝙛𝙧𝙤𝙢 𝙚𝙫𝙚𝙧𝙮 𝙨𝙩𝙧𝙞𝙣𝙜 𝙞𝙣 𝙖 𝙡𝙞𝙨𝙩.

# %%
letters = ["  Python  ", "  SQL", "Excel  ", "  Data Analytics  "]
remove = map(lambda x: x.strip(), letters)
print(list(remove))
# Out:
# ['Python', 'SQL', 'Excel', 'Data Analytics']

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟖 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙤𝙣𝙫𝙚𝙧𝙩 𝙚𝙫𝙚𝙧𝙮 𝙣𝙖𝙢𝙚 𝙞𝙣 𝙖 𝙡𝙞𝙨𝙩 𝙩𝙤 𝙪𝙥𝙥𝙚𝙧𝙘𝙖𝙨𝙚.

# %%
names = ["gourav", "rahul", "aman", "rohit"]
upper = map(lambda x: x.upper(), names)
print(list(upper))
# Out:
# ['GOURAV', 'RAHUL', 'AMAN', 'ROHIT']

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟏𝟗 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙖𝙡𝙘𝙪𝙡𝙖𝙩𝙚 𝙩𝙝𝙚 𝙨𝙦𝙪𝙖𝙧𝙚 𝙤𝙛 𝙤𝙣𝙡𝙮 𝙩𝙝𝙚 𝙥𝙤𝙨𝙞𝙩𝙞𝙫𝙚 𝙣𝙪𝙢𝙗𝙚𝙧𝙨.

# %%
numbers = [-3, 2, -5, 4, 0, 6]
square = map(lambda x: x ** 2 if x > 0 else 0 if x < 0 else 0, numbers)
print(list(square))
# Out:
# [0, 4, 0, 16, 0, 36]

# %% [markdown]
# ## 𝙌𝙪𝙚𝙨𝙩𝙞𝙤𝙣 : 𝟐𝟎 : 𝙒𝙧𝙞𝙩𝙚 𝙖 𝙋𝙮𝙩𝙝𝙤𝙣 𝙥𝙧𝙤𝙜𝙧𝙖𝙢 𝙪𝙨𝙞𝙣𝙜 𝙢𝙖𝙥() 𝙖𝙣𝙙 𝙖 𝙡𝙖𝙢𝙗𝙙𝙖 𝙛𝙪𝙣𝙘𝙩𝙞𝙤𝙣 𝙩𝙤 𝙘𝙤𝙣𝙫𝙚𝙧𝙩 𝙢𝙖𝙧𝙠𝙨 𝙞𝙣𝙩𝙤 𝙜𝙧𝙖𝙙𝙚𝙨.

# %%
marks = [85, 72, 45, 91, 33, 60]
grade = map(lambda x: "A" if x >= 80 else "B" if x >= 60 else "C" if x >= 40 else "Fail", marks)
print(list(grade))
# Out:
# ['A', 'B', 'C', 'A', 'Fail', 'B']
